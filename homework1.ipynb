# %%
import requests
import json
from pprint import pprint

# %% [markdown]
# 1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
url = 'https://api.github.com/users/LiyaDavletbakova/repos'

# %%
repos = requests.get(url)

# %%
pprint(repos.json())
# Out:
# [{'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/LiyaDavletbakova/Python_course/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/LiyaDavletbakova/Python_course/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/LiyaDavletbakova/Python_course/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/LiyaDavletbakova/Python_course/branches{/branch}',
#   'clone_url': 'https://github.com/LiyaDavletbakova/Python_course.git',
#   'collaborators_url': 'https://api.github.com/repos/LiyaDavletbakova/Python_course/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/LiyaDavletbakova/Python_course/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/LiyaDavletbakova/Python_course/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/LiyaDavletbakova/Python_course/compare/{base}...{head}',
# ...

# %%
repositories = []
for i in repos.json():
    repositories.append(i['name'])
print(repositories)
# Out:
# ['Python_course', 'python_for_data_science', 'repo_githab']

# %%
with open('repositories.json', 'w') as f:
    json_repo = json.dump(repositories, f)

# %% [markdown]
# 2. Изучить список открытых API (https://www.programmableweb.com/category/all/apis). Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.
# Если нет желания заморачиваться с поиском, возьмите API вконтакте (https://vk.com/dev/first_guide). Сделайте запрос, чтобы получить список всех сообществ на которые вы подписаны.

# %%
appid = 'a135a6746d489eea71f9999b07eff3ea'
url = 'https://samples.openweathermap.org/data/2.5/weather'
req = requests.get(f'{url}?q=London,uk&appid={appid}')
pprint(req.json())
# Out:
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 51.51, 'lon': -0.13},
#  'dt': 1485789600,
#  'id': 2643743,
#  'main': {'humidity': 81,
#           'pressure': 1012,
#           'temp': 280.32,
#           'temp_max': 281.15,
#           'temp_min': 279.15},
#  'name': 'London',
#  'sys': {'country': 'GB',
#          'id': 5091,
#          'message': 0.0103,
#          'sunrise': 1485762037,
#          'sunset': 1485794875,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'light intensity drizzle',
#               'icon': '09d',
#               'id': 300,
#               'main': 'Drizzle'}],
#  'wind': {'deg': 80, 'speed': 4.1}}

# %%
with open('weather.json', 'w') as g:
    json_repo_1 = json.dump(req.json(), g)
